# %% [markdown]
# # Day 1 — Python Basics Solutions
# This notebook runs the demo functions from `problems.py` and shows outputs for easy review and screenshots for LinkedIn.

# %%
import sys
sys.path.append('..')  # so we can import the module
from Day1_Python_Basics import problems

# %%
problems.demo_prints()

# %%
problems.list_examples()

# %%
data = [8, 2, 15, 1, 9]
smallest, largest = problems.find_min_max_no_builtin(data)
print('\nLargest number:', largest)
print('Smallest number:', smallest)

# %%
sports = ['Cricket', 'Football', 'Hockey', 'Football', 'Tennis', 'Football']
print('\nFootball count:', problems.count_occurrences_no_builtin(sports, 'Football'))

# %%
problems.while_loop_demo(limit=10)
problems.number_pattern(rows=5)

# %%
print('\nSum up to 10:', problems.sum_upto_n(10))

# %%
print('\nMultiplication table of 2:', problems.multiplication_table_of_2())

# %%
numbers = [12, 75, 150, 180, 145, 525, 50]
problems.conditional_loop_display(numbers)

# %%
problems.dictionary_operations_demo()

# %% [markdown]
# **End of notebook.**
#
# You can download `problems.py` from the repository folder and run it locally as well.
